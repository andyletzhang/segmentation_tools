# %%
import cupy

# %%
from cupyx.scipy import ndimage

# %%
import cellpose

# %%
from monolayer_tracking.segmented_comprehension import Image
import matplotlib.pyplot as plt

# %%
img=Image(r'Z:\Andy\segmentation\20240520 FUCCI halo ME 40x\tile7\tile7_seg.npy')

# %%
import numpy as np
import scipy.ndimage as ndimage

# %%
import cupy as cp
from cupyx.scipy import ndimage as ndi_GPU

# %%
CoMs=np.array(ndimage.center_of_mass(np.ones(img.resolution),img.masks,np.arange(1,img.n+1)))

# %%
cp_masks=cp.array(img.masks)

# %%
GPU_CoMs=cp.array(ndi_GPU.center_of_mass(cp.ones(img.resolution),cp_masks,cp.arange(1,img.n+1)))

# %%
plt.imshow(img.masks)
